# %%
# Построить график
import numpy as np
from math import *
import matplotlib.pyplot as plt

x = [31,48,51,54,61]
y = [19310/31,46204/48,52150/51,58456.19/54,74570/61]

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()

#  Наименование осей
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
  
plt.show()

# %%
def f(x, prise, meter, y):
    exp = ((meter) + (prise)*(x - y)) * x
    print(round(exp, 2))
    
cost_per_square_meter_1 = 19310/31 
cost_per_square_meter_2 = 52150/51 
average_prices_1 = (52150/51-19310/31)/(51-31)
average_prices_2 = (74570/61 - 52150/51)/(61-51)
y_1 =31
y_2 = 51

f(48,average_prices_1, cost_per_square_meter_1, y_1)
f(54,average_prices_2, cost_per_square_meter_2, y_2)
# Out:
# 46204.9
# 58456.19
